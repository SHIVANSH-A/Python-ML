# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\python38\lib\site-packages (0.11.1)
# Requirement already satisfied: pandas>=0.23 in d:\python38\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: numpy>=1.15 in c:\users\dell\appdata\roaming\python\python38\site-packages (from seaborn) (1.20.0)
# Requirement already satisfied: scipy>=1.0 in d:\python38\lib\site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: matplotlib>=2.2 in d:\python38\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pytz>=2020.1 in d:\python38\lib\site-packages (from pandas>=0.23->seaborn) (2021.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\python38\lib\site-packages (from pandas>=0.23->seaborn) (2.8.1)
# Requirement already satisfied: packaging>=20.0 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (5.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\python38\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six>=1.5 in d:\python38\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->seaborn) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 23.3.2 is available.
# You should consider upgrading via the 'd:\python38\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns

# %%
df=sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# f1 f2 f3 target Supervised ML
# Univariate Analysis

# %%
sns.jointplot(x="tip", y="total_bill", data=df, kind='hex')

# %%
sns.jointplot(x="tip", y="total_bill", data=df, kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="day")

# %%
sns.distplot(df['tip'])
# Out:
# d:\python38\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['tip'], kde=False, bins=10)
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# Categorical Column

# %%
sns.countplot("day", data=df)
# Out:
# d:\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(y="sex", data=df)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
# sns.barplot(x='total_bill',y='sex', data=df)
sns.barplot(y='total_bill',x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=df, palette='rainbow', orient='v')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="total_bill", data=df, palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="total_bill", y="day", data=df,palette='rainbow')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>
